# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import accuracy_score, log_loss, precision_score, recall_score

# %%
df = pd.read_csv('./../data/preprocessed_matches.csv')
df.head()
# Out:
#    match_id  season              kickoff          home_team  home_team_id  \
# 0    803169    2015  2015-08-08 12:45:00  Manchester United             1
# 1    803170    2015  2015-08-08 15:00:00            Everton            11
# 2    803162    2015  2015-08-08 15:00:00        Bournemouth            91
# 3    803163    2015  2015-08-08 15:00:00       Norwich City            45
# 4    803167    2015  2015-08-08 15:00:00     Leicester City            13
#
#    home_score          away_team  away_team_id  away_score outcome_label  ...  \
# 0           1  Tottenham Hotspur             6           0        H_or_D  ...
# 1           2            Watford            57           2        H_or_D  ...
# 2           0        Aston Villa             7           1             A  ...
# 3           1     Crystal Palace            31           3             A  ...
# 4           4         Sunderland            56           2        H_or_D  ...
#
#   home_pts_roll away_gf_roll  away_ga_roll  away_pts_roll  \
# 0           1.5          1.5           1.5            1.5
# 1           1.5          1.5           1.5            1.5
# 2           1.5          1.5           1.5            1.5
# 3           1.5          1.5           1.5            1.5
# 4           1.5          1.5           1.5            1.5
#
#    h2h_avg_points_home  h2h_avg_points_away  rest_days_home  rest_days_away  \
# 0                  1.0                  1.0             7.0             7.0
# 1                  1.0                  1.0             7.0             7.0
# 2                  1.0                  1.0             7.0             7.0
# 3                  1.0                  1.0             7.0             7.0
# 4                  1.0                  1.0             7.0             7.0
#
#    rest_days_diff  target
# 0             0.0       0
# 1             0.0       0
# 2             0.0       1
# 3             0.0       1
# 4             0.0       0
#
# [5 rows x 27 columns]

# %%
features = [
    'elo_home_pre', 'elo_away_pre', 'elo_diff_pre',
]

# %%
df = df[df['season'] != 2015]
df['season'].unique()
# Out:
# array([2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025])

# %%
xgb = xgb.XGBClassifier(
    n_estimators=100,
    max_depth=3,
    learning_rate=0.01543079811345041,
    subsample=1,
    colsample_bytree=0.8,
    random_state=42,
    objective="binary:logistic",
    eval_metric="logloss"
)

# %%
# Timeseries Cross-Validation
seasons = df["season"].unique()
fold_accuracy = []
fold_logloss = []
fold_precision = []
fold_recall = []
train_sizes = []
train_scores = []
test_scores = []

for i in range(1, len(seasons)):
    train_df = df[df["season"].isin(seasons[:i])]
    test_df = df[df["season"].isin([seasons[i]])]

    X_train = train_df[features]
    y_train = train_df['target']
    X_test = test_df[features]
    y_test = test_df['target']

    model = xgb.fit(X_train, y_train)

    pred_labels = model.predict(X_test)
    preds_test = model.predict_proba(X_test)[:, 1]
    preds_train = model.predict_proba(X_train)[:, 1]

    pred_labels = (preds_test >= 0.5).astype(int)

    fold_accuracy.append(accuracy_score(y_test, pred_labels))
    fold_logloss.append(log_loss(y_test, preds_test))
    fold_precision.append(precision_score(y_test, pred_labels, average='binary'))
    fold_recall.append(recall_score(y_test, pred_labels, average='binary'))
    print(f"Lightgbm(n_estimators=500, max_depth=50) \n"
          f"Train({seasons[:i]}) with Test ({[seasons[i]]} \n"
          f"Accuracy: {accuracy_score(y_test, pred_labels)}, "
          f"Logloss: {log_loss(y_test, preds_test)}, "
          f"Precision: {precision_score(y_test, pred_labels, average='binary')}, "
          f"Recall: {recall_score(y_test, pred_labels, average='binary')}")

    train_sizes.append(len(train_df))
    test_scores.append(log_loss(y_test, preds_test))
    train_scores.append(log_loss(y_train, preds_train))

print("---------------------------Final---------------------------")
print(f"XgBoost"
      f"Accuracy: {np.mean(fold_accuracy)}, Logloss: {np.mean(fold_logloss)}, Precision: {np.mean(fold_precision)}, Recall: {np.mean(fold_recall)}")
# Out:
# Lightgbm(n_estimators=500, max_depth=50)
# Train([2016]) with Test ([2017]
# Accuracy: 0.7631578947368421, Logloss: 0.5172000344189822, Precision: 0.6071428571428571, Recall: 0.4722222222222222
# Lightgbm(n_estimators=500, max_depth=50)
# Train([2016 2017]) with Test ([2018]
# Accuracy: 0.7342105263157894, Logloss: 0.5512989544131702, Precision: 0.6753246753246753, Recall: 0.40625
# Lightgbm(n_estimators=500, max_depth=50)
# Train([2016 2017 2018]) with Test ([2019]
# Accuracy: 0.7, Logloss: 0.55331363333337, Precision: 0.5119047619047619, Recall: 0.3706896551724138
# Lightgbm(n_estimators=500, max_depth=50)
# Train([2016 2017 2018 2019]) with Test ([2020]
# Accuracy: 0.618421052631579, Logloss: 0.6824980374692738, Precision: 0.5952380952380952, Recall: 0.16339869281045752
# Lightgbm(n_estimators=500, max_depth=50)
# Train([2016 2017 2018 2019 2020]) with Test ([2021]
# Accuracy: 0.7263157894736842, Logloss: 0.5653816594918322, Precision: 0.6865671641791045, Recall: 0.35658914728682173
# Lightgbm(n_estimators=500, max_depth=50)
# Train([2016 2017 2018 2019 2020 2021]) with Test ([2022]
# Accuracy: 0.7210526315789474, Logloss: 0.546988146137167, Precision: 0.5272727272727272, Recall: 0.26605504587155965
# Lightgbm(n_estimators=500, max_depth=50)
# Train([2016 2017 2018 2019 2020 2021 2022]) with Test ([2023]
# Accuracy: 0.7368421052631579, Logloss: 0.5408004316529399, Precision: 0.6949152542372882, Recall: 0.3333333333333333
# Lightgbm(n_estimators=500, max_depth=50)
# Train([2016 2017 2018 2019 2020 2021 2022 2023]) with Test ([2024]
# Accuracy: 0.6860158311345647, Logloss: 0.5860457682724568, Precision: 0.6226415094339622, Recall: 0.25
# Lightgbm(n_estimators=500, max_depth=50)
# Train([2016 2017 2018 2019 2020 2021 2022 2023 2024]) with Test ([2025]
# Accuracy: 0.7277777777777777, Logloss: 0.55339477237324, Precision: 0.6153846153846154, Recall: 0.2909090909090909
# ---------------------------Final---------------------------
# XgBoost(n_estimators=500, max_depth=50) Accuracy: 0.7126437343235936, Logloss: 0.5663246041736036, Precision: 0.6151546289020096, Recall: 0.3232719097339888

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.plot(train_sizes, fold_accuracy, marker='o', label="Accuracy")
plt.plot(train_sizes, fold_logloss, marker='o', label="Log Loss")

plt.xlabel("Number of training samples")
plt.ylabel("Performance")
plt.title("Learning Curve (Expanding Window Time Series)")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(train_sizes, train_scores, label="Training Log Loss")
plt.plot(train_sizes, test_scores, label="Test Log Loss")
plt.xlabel("Number of training samples")
plt.ylabel("Log Loss (Lower is better)")
plt.legend()
plt.show()
