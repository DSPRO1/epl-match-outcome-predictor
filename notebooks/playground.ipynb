# %%
import pandas as pd

# %%
data = pd.read_csv("./../data/preprocessed_matches.csv")

# %%
# Out:
# match_id                 int64
# season                   int64
# kickoff                 object
# home_team               object
# home_team_id             int64
# home_score               int64
# away_team               object
# away_team_id             int64
# away_score               int64
# outcome_label           object
# winner_label            object
# kickoff_datetime        object
# elo_home_pre           float64
# elo_away_pre           float64
# elo_diff_pre           float64
# home_gf_roll           float64
# home_ga_roll           float64
# home_pts_roll          float64
# away_gf_roll           float64
# away_ga_roll           float64
# away_pts_roll          float64
# h2h_avg_points_home    float64
# h2h_avg_points_away    float64
# rest_days_home         float64
# rest_days_away         float64
# rest_days_diff         float64
# target                   int64
# dtype: object

# %%
data[(data['h2h_avg_points_home'] == 3) & (data['season'] > 2020)]
# Out:
#       match_id  season              kickoff                 home_team  \
# 2341   2210332    2021  2021-10-02 15:00:00                   Burnley
# 2361   2210354    2021  2021-10-23 12:30:00                   Chelsea
# 2404   2210393    2021  2021-11-27 17:30:00  Brighton and Hove Albion
# 2454   2210452    2021  2021-12-26 20:00:00  Brighton and Hove Albion
# 2480   2210489    2021  2022-01-16 14:00:00           West Ham United
# 2488   2210492    2021  2022-01-22 15:00:00                 Brentford
# 2499   2210508    2021  2022-02-09 19:45:00           Manchester City
# 2538   2210547    2021  2022-03-05 15:00:00              Norwich City
# 2556   2210557    2021  2022-03-13 14:00:00              Leeds United
# 2566   2210563    2021  2022-03-20 14:00:00            Leicester City
# 2572   2210573    2021  2022-04-02 15:00:00                   Chelsea
# 2586   2210583    2021  2022-04-10 14:00:00                 Brentford
# ...

# %%
data[((data['home_team'] == 'Manchester City') | (data['away_team'] == 'Manchester City')) & ((data['home_team'] == 'Bournemouth') | (data['away_team'] == 'Bournemouth'))]
# Out:
#       match_id  season              kickoff        home_team  home_team_id  \
# 82      803244    2015  2015-10-17 15:00:00  Manchester City            43
# 309     803475    2015  2016-04-02 15:00:00      Bournemouth            91
# 421     855217    2016  2016-09-17 15:00:00  Manchester City            43
# 629     855412    2016  2017-02-13 20:00:00      Bournemouth            91
# 780     918913    2017  2017-08-26 12:30:00      Bournemouth            91
# 943     919078    2017  2017-12-23 15:00:00  Manchester City            43
# 1272    987729    2018  2018-12-01 15:00:00  Manchester City            43
# 1420    987872    2018  2019-03-02 15:00:00      Bournemouth            91
# 1547   1059722    2019  2019-08-25 14:00:00      Bournemouth            91
# 1873   1060058    2019  2020-07-15 18:00:00  Manchester City            43
# 2673   2292826    2022  2022-08-13 15:00:00  Manchester City            43
# ...
